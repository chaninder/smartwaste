# %%
# %%capture
! pip install git+https://github.com/huggingface/huggingface_hub.git@main
! sudo apt -qq install git-lfs
! git config --global credential.helper store

# %%
! huggingface-cli login
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
import tensorflow as tf
from tensorflow import keras

from huggingface_hub import push_to_hub_keras

# %%
pwd
# Out:
# '/content'

# %%
model_path = "/content/drive/MyDrive/prod7"
pre_trained_model = keras.models.load_model(model_path)

# %%
pre_trained_model

# %%
# push pre-trained custom model to Keras
push_to_hub_keras(pre_trained_model, 'waste-sorting-model-v4')
# Out:
# Cloning https://huggingface.co/chaninder/waste-sorting-model-v4 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/chaninder/waste-sorting-model-v4 into local empty directory.
# WARNING:absl:Found untraced functions such as restored_function_body, restored_function_body, restored_function_body, restored_function_body, restored_function_body while saving (showing 5 of 53). These functions will not be directly callable after loading.
# Adding files tracked by Git LFS: ['variables/variables.data-00000-of-00001', 'model.png', 'variables/variables.index']. This may take a bit of time if the files are large.
# WARNING:huggingface_hub.repository:Adding files tracked by Git LFS: ['variables/variables.data-00000-of-00001', 'model.png', 'variables/variables.index']. This may take a bit of time if the files are large.
# Upload file variables/variables.data-00000-of-00001:   0%|          | 3.34k/10.2M [00:00<?, ?B/s]
# ...

# %%
# add these lines to gradio app.py file
from huggingface_hub import from_pretrained_keras

model_api_link = 'chaninder/waste-sorting-model'
pre_trained_model = from_pretrained_keras(model_api_link)
